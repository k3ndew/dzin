# %%
a = set()
a.add(2)
a.add(3)
b = set()
b.add(3)
b.add(4)
s = a &b
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = set()
# ----> 2 a.add(2,3)
#       3 b = set()
#       4 b.add(3,4)
#
# TypeError: set.add() takes exactly one argument (2 given)
